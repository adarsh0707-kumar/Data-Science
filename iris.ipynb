# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.displot(x = df.sepal_length)

# %%
sns.displot(x = df.sepal_width)

# %%
sns.displot(x = df.petal_length)

# %%
sns.displot(x =df.petal_width)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Outliers for sepal_length
#
# min = 4.3
# Q1 = 5.1
# Q2 = 5.8
# Q3 = 6.4
# max = 7.9
#
# whis value = 1.5
#
# IQR = 6.4 - 5.1
#     = 1.3
# IQR max = Q3 + 1.5 * IQR
#         = 6.4 + 1.5 * 1.3 = 8.35
# IQR min = Q1 - 1.5 * IQR
#         = 5.1 - 1.5 * 1.3 = 3.15
# lower whisker = 3.15 to 5.1
# upper whisker = 6.4 to 7.9
#
# lower outlier = None
# upper outlier = None

# %%
sns.boxplot(x= df.sepal_length)
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# Outlier of sepal witdh
#
# min = 2
# Q1 = 2.8
# Q2 = 3
# Q3 = 3.3
# max = 4.4
#
# IQR = 3.3 - 2.8
#     = .5
# IQR max = Q3 + 1.5 * IQR
#         = 3.3 + 1.5 * .5 = 4.05
# IQR min = Q1 - 1.5 * IQR
#         = 2.8 - 1.5 * .5 = 2.05
# lower whisker = 2.05 to 2.8
# upper whisker = 4.05 to 4.4
#
# lower outlier = 2 to 2.05
# upper outlier = 4.05 to 4.4

# %%
sns.boxplot(x= df.sepal_width)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
sns.regplot(x=df.petal_length, y=df.sepal_length)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.pairplot(df, kind='reg')

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.pairplot(df, kind='reg', hue = 'species')
