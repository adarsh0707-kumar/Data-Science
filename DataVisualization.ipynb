# %% [markdown]
# Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
t = sns.load_dataset('titanic')
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)
z = np.cos(x)

fig = plt.figure(figsize= (8,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label='Sine Wave', color='blue')
ax.plot(x,z, label='Cosine Wave', color='red')

ax.legend()

ax.set_xlabel("Angle")
ax.set_ylabel("Co/sine's Angle")
ax.set_title("Co/sine Function")
plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = 1/(np.sin(x))
z = 1/(np.cos(x))
fig = plt.figure(figsize= (8,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label='Cosecant Wave', color='blue')
ax.plot(x,z, label='Secant Wave', color='red')  
ax.legend()
ax.set_xlabel("Angle")
ax.set_ylabel("Co/secant's Angle")
ax.set_title("Co/secant Function")
plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.tan(x)
z = 1/(np.tan(x))
fig = plt.figure(figsize= (8,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label='Tangent Wave', color='blue')
ax.plot(x,z, label='Cotangent Wave', color='red')
ax.legend()
ax.set_xlabel("Angle")
ax.set_ylabel("Co/tangent's Angle")
ax.set_title("Co/tangent Function")
plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.1)

y = np.log10(x)
z = np.log2(x)
fig = plt.figure(figsize= (8,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label='Logarithmic Wave of log10', color='blue')
ax.plot(x,z, label='Logarithmic Wave of log2', color='red')
ax.legend()
ax.set_xlabel("Angle")
ax.set_ylabel("Logarithmic of Angle")
ax.set_title("Logarithmic Function")
plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)
z = np.tan(x)

fig = plt.figure(figsize= (8,5))
ax1 = fig.add_axes([0,0,1,0.45])
ax2 = fig.add_axes([0,0.5,1,0.55])

ax1.plot(x,y, label='Sine Wave', color='blue')
ax1.legend()
ax1.set_xlabel("Angle")
ax1.set_ylabel("Sine of Angle")
ax1.set_title("Sine Function")


ax2.plot(x,z, label='tan Wave', color='red')
ax2.legend()
ax2.set_ylabel("tan of Angle")
ax2.set_title("tan Function")
plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.1) 
y = np.sin(x)
z = np.cos(x)
p = np.tan(x)
q = np.log10(x)

fig = plt.figure(figsize=(10,7))

ax1 = fig.add_axes([0,0,0.45,0.45])
ax2 = fig.add_axes([0.55,0,0.45,0.45])
ax3 = fig.add_axes([0,0.55,0.45,0.45])
ax4 = fig.add_axes([0.55,0.55, 0.45,0.45])

ax1.plot(x,y, label='Sine', color='green')
ax2.plot(x,z, label='Cosine', color= 'black')
ax3.plot(x,p, label='Tan', color= 'red')
ax4.plot(x,q, label='Log')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

# %%
ta = t.groupby('sibsp').age.mean()
ta
# Out:
# sibsp
# 0    31.397558
# 1    30.089727
# 2    22.620000
# 3    13.916667
# 4     7.055556
# 5    10.200000
# 8          NaN
# Name: age, dtype: float64

# %%
x = ta.index
y = ta.values

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.bar(x,y)

for i, value in zip(x,y):
  plt.text(i, value - 4, str(round(value, 2)), ha='center', color = 'yellow', fontweight = 800, fontsize=12)

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
tp = t.pclass.value_counts()
tp
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
x = tp.index
y = tp.values

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.set_xticks([1,2,3], ['1st Class', '2nd Class', '3rd Class'])
ax.bar(x,y)

for i, value in zip(x,y):
  plt.text(i, value -50, str(value), ha='center', color = 'yellow', fontweight = 800, fontsize=12)

# %%
tsibsp = t.groupby('sibsp').age.mean()

tsex = t.groupby('sex').age.mean()

tsurvived = t.groupby('survived').age.mean()

tparch = t.groupby('parch').age.mean()

fig = plt.figure(figsize=(10,7))


ax1 = fig.add_axes([0,0,0.45,0.45])
ax2 = fig.add_axes([0.55,0,0.45,0.45])
ax3 = fig.add_axes([0,0.55,0.45,0.45])
ax4 = fig.add_axes([0.55,0.55, 0.45,0.45])


ax1.bar(tsibsp.index, tsibsp.values , label='Sibsp')
ax2.bar(tsex.index, tsex.values, width=0.5, label='Sex')
ax3.bar(tsurvived.index, tsurvived.values, width=0.5, label='Survived')
ax4.bar(tparch.index, tparch.values, label='Parch')

ax3.set_xticks([0,1], ['Survived', 'Not Survived'])

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()



plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = fig.add_axes([0,0,1,1])

ax.hist(t.age)
ax.set_xlabel('Age')
ax.set_ylabel('Number of Passengers')
ax.set_title('Frequency of Age')
plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = fig.add_axes([0,0,1,1])

ax.hist(t.fare, bins=35)
ax.set_xlabel('Fare')
ax.set_ylabel('Cost of Passengers')
ax.set_title('Frequency of fare')
plt.show()

# %%
tp = t.pclass.value_counts()
x = tp.index
y = tp.values

plt.pie(y,labels = x, autopct = '%.2f%%')
plt.show()

# %%
i = sns.load_dataset('iris')
i
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
si = i.species.value_counts()
x = si.index
y = si.values

plt.pie(y,labels = x, autopct = '%.2f%%')
plt.show()

# %%
plt.boxplot(t[t.age.notnull()].age, vert=False)
plt.show()

# %%
plt.boxplot(t.fare, vert=False)
plt.show()

# %% [markdown]
# HeatMaP

# %%
tc = t.corr(numeric_only = True)
tc
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(tc, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# Displot

# %%
sns.displot(t.age)

# %%
sns.histplot(t.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# KDE plot
# Kernel Density Estimation

# %%
sns.kdeplot(t.age)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.displot(t.age, kde=True)

# %% [markdown]
# Barplot

# %%
sns.barplot(x = t.sex, y = t.age, hue=t.pclass)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(x=t.sex, hue=t.embarked)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=t.pclass)
x=t.pclass
y = t.pclass.value_counts()

# for i, value in zip(x,y):
#   plt.text(i, value, str(value), ha='center', color = 'yellow', fontweight = 800, fontsize=12)

# %%
sns.scatterplot(x=t.age, y = t.fare, hue= t.sex, style=t.pclass)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.hexplot(x=t.age, y=t.fare)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 sns.hexplot(x=t.age, y=t.fare)
#
# AttributeError: module 'seaborn' has no attribute 'hexplot'

# %%
sns.jointplot(x=t.age, y=t.fare)

# %%
sns.jointplot(x=t.age, y=t.fare, kind='hex')

# %%
sns.regplot(x=t.age, y=t.fare)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.jointplot(x=t.age, y=t.fare, kind='kde')

# %%
sns.boxplot(x=t.age)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x=t.age, y=t.sex)
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.boxplot(x=t.age, y=t.sex, hue=t.pclass)
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.pairplot(t, kind='reg')

# %% [markdown]
# Given a taple
# t = ("Python", "java", "c", "c++")

# %%
a,b,c,d = ("Python", "java", "c", "c++")
print(a)
print(b)
print(c)
print(d)
# Out:
# Python
# java
# c
# c++

# %% [markdown]
# Write a program to rotate a list n time without using extra space

# %%
def reverse(arr, start, end):
  while start < end:
    arr[start], arr[end] = arr[end], arr[start]
    start += 1
    end -= 1


def rotate(arr, n):
  size = len(arr)
  n = n% size #in case n> size
  # reverse whole arr
  reverse(arr,0,size-1)
  
  #reverse the first n element 

  reverse(arr,0, n-1)

  reverse(arr, n, size-1)

arr =[1,2,3,4,5,6,7]
n = 3
rotate(arr,n)
print("Rotated List", arr)
# Out:
# Rotated List [5, 6, 7, 1, 2, 3, 4]

# %% [markdown]
# Find the 2nd largest unique element from a list without using max() or short()

# %%
def second_largest_unique(arr):
  largest = float('-inf')
  second = float('-inf')
  for num in arr:
    if num > largest:
      second = largest
      largest = num
    elif num > second and num != largest:
      second = num
  if  second == float('-inf'):
    return None
  return second

arr = [10,20,4,20,10,5]
print("Second largest unique element: ", second_largest_unique(arr))
# Out:
# Second largest unique element:  10

# %%
def second_largest_unique(lst):
    unique_values = set(lst)
    if len(unique_values) < 2:
        return None  

    largest = second = float('-inf')

    for num in lst:
        if num > largest:
            second, largest = largest, num
        elif num != largest and num > second:
            second = num

    return second

arr = [10,20,4,20,10,5]
print("Second largest unique element: ", second_largest_unique(arr))
# Out:
# Second largest unique element:  10

# %% [markdown]
# Given two tappls create a program to find the all common elements from them. without using set.

# %%
t1 = (1, 2, 3, 4, 5, 6)
t2 = (4, 3, 0, 9, 5, 9, 10, 45)
t = []  

for i in t1:
  for j in t2:
    if i == j:
      t.append(i) 
print(t)
# Out:
# [3, 4, 5]

# %% [markdown]
# Write a dic ptogram that group the words using anagram

# %%
def group_anagrams(words):
  anagram_map = {}
  for word in words:
    key = ''.join(sorted(word))  
    if key in anagram_map:
      anagram_map[key].append(word)
    else:
      anagram_map[key] = [word]
  return list(anagram_map.values())


words = ["eat", "tea", "tan", "ate", "nat", "bat"]
print(group_anagrams(words))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# From a tapple of string find the longest stings.

# %%
t = ("sdgre", "we4rtgv", "dfgteedsdg", "ert")
t1 = []
for i in t:
  a = len(i)
  t1.append(a)
print(t1)
# Out:
# [5, 7, 10, 3]
